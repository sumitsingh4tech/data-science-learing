# %% [markdown]
# **8.4. High-Performance Serving with vLLM on EC2**

# %%
# !pip install -q openai
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
from openai import OpenAI

# replace with your EC2 instance Public IPv4 address or "localhost" if running locally
client = OpenAI(
    base_url="http://3.89.191.116:8000/v1",
    api_key="EMPTY"
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "What is Machine Learning?",
        }
    ],
    model="Qwen/Qwen2.5-1.5B-Instruct",
)

print(chat_completion.choices[0].message.content)
# Out:
# Machine learning (ML) is an application of artificial intelligence (AI) and computer science that aims to develop algorithms and statistical models that allow computers to improve their performance in specific tasks with experience or data exposure.
#
# The goal of machine learning is to create systems that can learn from data without being explicitly programmed. These systems use statistical techniques to automatically identify patterns and make predictions based on those patterns.
#
# Machine learning has many applications, including image recognition, natural language processing, speech recognition, recommendation systems, fraud detection, autonomous vehicles, and more.
#
# There are different types of machine learning, such as supervised learning, unsupervised learning, reinforcement learning, and semi-supervised learning. Each type of machine learning focuses on different aspects of learning and solving problems.
#
# ...

# %%
from langchain_community.llms import VLLMOpenAI

llm = VLLMOpenAI(
    openai_api_key="EMPTY",
    openai_api_base="http://3.89.191.116:8000/v1",
    model_name="Qwen/Qwen2.5-1.5B-Instruct",
)
print(llm.invoke("Machine Learning is"))
# Out:
#  a branch of artificial intelligence. It involves methods and algorithms that allow computers to learn from data without being explicitly programmed.
# The term machine learning was coined by Arthur Samuel in 1959, referring to the ability of machines to automatically improve their performance on tasks through experience. The field has been developed since then and there are many types of machine learning techniques used today including supervised learning, unsupervised learning, semi-supervised learning, reinforcement learning, decision trees, neural networks, support vector machines etc.
# In short, it can be defined as "machine learning is how we teach computers."
# There are lots of ways to explain what Machine Learning is; here’s one:
# "Machine learning is an interdisciplinary field which uses statistical techniques to give computer systems the capability to learn from data without being explicitly programmed."
# ...
